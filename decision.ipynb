# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("TRANSFORMER DATA SET CSV.csv")

# %%
df.tail()
# Out:
#      S.NO  OIL LEVEL  OIL TEMP  WINDING TEMP  CLASS
# 595   596       76.0        77            78      0
# 596   597       79.0        79            79      0
# 597   598       26.0        27            28      1
# 598   599       29.0        30            31      1
# 599   600       76.0        77            78      0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   S.NO          600 non-null    int64
#  1   OIL LEVEL     598 non-null    float64
#  2   OIL TEMP      600 non-null    int64
#  3   WINDING TEMP  600 non-null    int64
#  4   CLASS         600 non-null    int64
# dtypes: float64(1), int64(4)
# memory usage: 23.6 KB

# %%
print(df.columns)
# Out:
# Index(['S.NO', 'OIL LEVEL', 'OIL TEMP', 'WINDING TEMP', 'CLASS'], dtype='object')

# %%
X=df.drop('CLASS',axis=1)

# %%
X.head()
# Out:
#    S.NO  OIL LEVEL  OIL TEMP  WINDING TEMP
# 0     1       38.0        25            34
# 1     2       39.0        26            35
# 2     3       40.0        27            36
# 3     4       30.0        28            37
# 4     5       32.0        29            38

# %%
y=df['CLASS']

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 595    0
# 596    0
# 597    1
# 598    1
# 599    0
# Name: CLASS, Length: 600, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print(X.shape)
# Out:
# (600, 4)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model= DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
model.predict(X_train)
y_pred=model.predict(X_test)

# %%
from sklearn import metrics

# %%
print(metrics.accuracy_score(y_test,y_pred))
# Out:
# 1.0

# %%
import pickle
pickle.dump(model,open('monitor1.pkl','wb'))
